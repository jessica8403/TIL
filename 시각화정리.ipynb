# %% [markdown]
# <a href="https://colab.research.google.com/github/jessica8403/TIL/blob/master/%EC%8B%9C%EA%B0%81%ED%99%94%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('font', family='NanumGothicCoding')

# %%
from matplotlib import font_manager, rcParams
# !apt-get install fonts-nanum*
rcParams['font.family'] = 'NanumGothicCoding'
rcParams['axes.unicode_minus'] = False
font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-gothic-light' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# fonts-nanum is already the newest version (20170925-1).
# fonts-nanum-coding is already the newest version (2.5-1).
# fonts-nanum-eco is already the newest version (1.000-6).
# fonts-nanum-extra is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
df1=pd.read_excel('/content/drive/MyDrive/시군구별 출산율_서울특별시 .xlsx',index_col='연도')

# %%
df1
# Out:
#       서울특별시
# 연도
# 2010  1.015
# 2011  1.014
# 2012  1.059
# 2013  0.968
# 2014  0.983
# 2015  1.001
# 2016  0.940
# 2017  0.836
# 2018  0.761
# 2019  0.717
# 2020  0.642

# %% [markdown]
# 서울특별시 출생률

# %%
import folium  
import json

# %%
geo_path = '/content/drive/MyDrive/seoulsigungu.geojson'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
df3=pd.read_excel('/content/drive/MyDrive/연간평균.xlsx',index_col='지역')

# %%
df3 #2010년-2020년 출생률
# Out:
#          평균
# 지역
# 종로구   0.739
# 중구    0.918
# 용산구   0.904
# 성동구   0.988
# 광진구   0.816
# 동대문구  0.875
# 중랑구   0.936
# 성북구   0.902
# 강북구   0.857
# 도봉구   0.922
# 노원구   0.990
# 은평구   0.921
# 서대문구  0.863
# 마포구   0.861
# 양천구   0.920
# 강서구   0.984
# 구로구   1.044
# 금천구   0.926
# 영등포구  0.978
# 동작구   0.894
# 관악구   0.746
# 서초구   0.920
# 강남구   0.768
# 송파구   0.931
# 강동구   0.957

# %%
df3.index
# Out:
# Index(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구',
#        '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구',
#        '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='지역')

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='stamentoner')
map.choropleth(geo_data=geo_str,
              data=df3,
              columns=[df3.index, '평균'],
              fill_color='PuRd',
              key_on = 'properties.SIG_KOR_NM')
map
# Out:
# /usr/local/lib/python3.7/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# ...

# %%
#2010-2020년 서울특별시 출생률 
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,5)

# df1.plot()
# plt.show()

df1_1=df1.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df1_1.set_xlabel('연도')
df1_1.set_ylabel('출생률')
df1_1.set_title('서울특별시 출생률')
df1_1.plot(size=(15,10))

plt.show()

# %% [markdown]
# 서울시 구역별 출생률

# %%
df2=pd.read_csv('/content/drive/MyDrive/출생률평균_지역별.csv',index_col='연도',encoding='cp949')

# %%
df2
# Out:
#         도심권    동남권    동북권    서남권    서북권
# 연도
# 2010  0.970  1.021  1.020  1.038  0.982
# 2011  0.972  1.007  1.017  1.042  0.978
# 2012  1.036  1.045  1.064  1.088  1.032
# 2013  0.897  0.957  0.977  0.989  0.951
# 2014  0.924  0.978  0.982  1.014  0.966
# 2015  0.921  0.978  1.004  1.050  0.967
# 2016  0.888  0.907  0.946  0.969  0.941
# 2017  0.754  0.815  0.858  0.863  0.814
# 2018  0.697  0.763  0.771  0.774  0.744
# 2019  0.714  0.714  0.731  0.724  0.688
# 2020  0.615  0.652  0.649  0.651  0.634

# %%
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,7)

# df2.plot()
# plt.show()

df2_1=df2.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df2_1.set_xlabel('연도')
df2_1.set_ylabel('출생률')
df2_1.set_title('서울구역별 출생률')
df2_1.plot(size=(15,10))
plt.show()

# %% [markdown]
# 도심권

# %%
df4=pd.read_excel('/content/drive/MyDrive/시군구별 출산율_도심권 .xlsx',index_col='연도')

# %%
df4
# Out:
#       　　　종로구  　　　중구  　　　용산구
# 연도
# 2010   0.837  1.055   1.017
# 2011   0.860  1.017   1.039
# 2012   0.890  1.121   1.098
# 2013   0.729  0.955   1.008
# 2014   0.790  1.004   0.978
# 2015   0.813  0.946   1.005
# 2016   0.784  0.974   0.907
# 2017   0.646  0.824   0.793
# 2018   0.606  0.737   0.747
# 2019   0.648  0.780   0.713
# 2020   0.522  0.688   0.634

# %%
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,7)

# df4.plot()
# plt.show()


df4_1=df4.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df4_1.set_xlabel('연도')
df4_1.set_ylabel('출생률')
df4_1.set_title('도심권 출생률')
df4_1.plot(size=(10,7))
plt.show()

# %% [markdown]
# 동남권

# %%
df5=pd.read_excel('/content/drive/MyDrive/시군구별 출산율_동남권 .xlsx',index_col='연도')

# %%
df5
# Out:
#       　　　서초구  　　　강남구  　　　송파구  　　　강동구
# 연도
# 2010   1.068   0.862   1.058   1.096
# 2011   1.025   0.855   1.042   1.104
# 2012   1.095   0.886   1.099   1.101
# 2013   1.007   0.842   0.973   1.006
# 2014   1.014   0.863   0.996   1.039
# 2015   1.012   0.857   1.008   1.036
# 2016   0.928   0.802   0.958   0.938
# 2017   0.799   0.706   0.871   0.884
# 2018   0.800   0.631   0.800   0.820
# 2019   0.715   0.612   0.770   0.758
# 2020   0.656   0.537   0.665   0.748

# %%
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,7)

# df5.plot()
# plt.show()


df5_1=df5.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df5_1.set_xlabel('연도')
df5_1.set_ylabel('출생률')
df5_1.set_title('동남권 출생률')
df5_1.plot(size=(10,7))
plt.show()

# %% [markdown]
# 동북권

# %%
df6=pd.read_excel('/content/drive/MyDrive/시군구별 출산율_동북권 .xlsx',index_col='연도')

# %%
df6
# Out:
#       　　　성동구  　　　광진구  　　　동대문구  　　　중랑구  　　　성북구  　　　강북구  　　　도봉구  　　　노원구
# 연도
# 2010   1.029   0.935    0.941   1.010   1.048   0.996   1.104   1.100
# 2011   1.026   0.900    0.975   0.996   1.062   1.018   1.079   1.083
# 2012   1.077   0.957    0.998   1.082   1.044   1.051   1.137   1.162
# 2013   1.079   0.877    0.909   0.991   0.983   0.963   0.956   1.057
# 2014   1.027   0.895    0.914   1.006   0.949   0.955   1.000   1.109
# 2015   1.095   0.903    0.960   1.051   0.991   0.922   1.010   1.096
# 2016   1.013   0.867    0.889   0.995   0.909   0.878   0.947   1.068
# 2017   0.972   0.749    0.822   0.906   0.818   0.825   0.833   0.938
# 2018   0.909   0.713    0.753   0.825   0.737   0.647   0.774   0.809
# 2019   0.855   0.652    0.765   0.777   0.707   0.617   0.697   0.776
# 2020   0.783   0.527    0.699   0.660   0.676   0.550   0.601   0.695

# %%
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,7)

# df6.plot()
# plt.show()


df6_1=df6.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df6_1.set_xlabel('연도')
df6_1.set_ylabel('출생률')
df6_1.set_title('동북권 출생률')
df6_1.plot(size=(10,7))
plt.show()

# %% [markdown]
# 서남권

# %%
df7=pd.read_excel('/content/drive/MyDrive/시군구별 출산율_서남권 .xlsx',index_col='연도')

# %%
df7
# Out:
#       　　　양천구  　　　강서구  　　　구로구  　　　금천구  　　　영등포구  　　　동작구  　　　관악구
# 연도
# 2010   0.974   1.085   1.197   1.011    1.128   0.989   0.881
# 2011   1.002   1.113   1.177   1.001    1.103   1.001   0.897
# 2012   1.055   1.151   1.258   1.104    1.142   1.017   0.891
# 2013   0.990   1.032   1.162   0.944    0.999   0.974   0.825
# 2014   1.005   1.064   1.142   1.019    1.025   1.007   0.834
# 2015   1.034   1.129   1.169   1.086    1.085   1.012   0.833
# 2016   1.008   1.059   1.070   0.944    1.011   0.912   0.777
# 2017   0.898   0.925   0.943   0.901    0.884   0.831   0.662
# 2018   0.771   0.826   0.838   0.796    0.851   0.737   0.597
# 2019   0.742   0.760   0.794   0.709    0.829   0.697   0.536
# 2020   0.644   0.675   0.737   0.668    0.705   0.655   0.474

# %%
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,7)

# df7.plot()
# plt.show()


df7_1=df7.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df7_1.set_xlabel('연도')
df7_1.set_ylabel('출생률')
df7_1.set_title('서남권 출생률')
df7_1.plot(size=(10,7))
plt.show()

# %% [markdown]
# 서북권

# %%
df8=pd.read_excel('/content/drive/MyDrive/시군구별 출산율_서북권 .xlsx',index_col='연도')

# %%
df8
# Out:
#       　　　은평구  　　　서대문구  　　　마포구
# 연도
# 2010   1.020    0.971   0.955
# 2011   1.064    0.894   0.977
# 2012   1.139    0.967   0.991
# 2013   1.024    0.938   0.892
# 2014   1.028    0.954   0.915
# 2015   1.003    0.913   0.986
# 2016   0.943    0.934   0.945
# 2017   0.814    0.823   0.806
# 2018   0.772    0.727   0.733
# 2019   0.697    0.685   0.681
# 2020   0.623    0.685   0.594

# %%
# matplotlib.rcParams['font.family']='NanumGothicCoding'
# matplotlib.rcParams['axes.unicode_minus']=False
# plt.rcParams["figure.figsize"] = (10,7)

# df8.plot()
# plt.show()


df8_1=df8.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df8_1.set_xlabel('연도')
df8_1.set_ylabel('출생률')
df8_1.set_title('서북권 출생률')
df8_1.plot(size=(10,7))
plt.show()

# %% [markdown]
# 서울특별시 주택매매가격 증감율과 출산 증감율과의 관계 (주택범위-아파트,단독주택,연립주택,다세대주택,다가구주택)

# %%
df9=pd.read_excel('/content/drive/MyDrive/연주택매매증가율.xlsx',index_col='연도')

# %%
df9
# Out:
#       주택증감율
# 연도
# 2010   -1.2
# 2011    0.3
# 2012   -2.9
# 2013   -1.4
# 2014    1.1
# 2015    4.6
# 2016    2.1
# 2017    3.6
# 2018    6.2
# 2019    1.3
# 2020    2.7

# %%
df10=pd.read_excel('/content/drive/MyDrive/연간출생증감율수정.xls',index_col='연도')

# %%
df10
# Out:
#         증감율
# 연도
# 2010   4.10
# 2011  -1.87
# 2012   2.61
# 2013 -10.49
# 2014  -0.42
# 2015  -0.84
# 2016  -9.00
# 2017 -13.43
# 2018 -11.19
# 2019  -7.58
# 2020 -11.60

# %%
df10.rename(columns= {'증감율' : '출생증감율'},
    inplace = True)

# %%
df11=df9.join(df10)

# %%
df11
# Out:
#       주택증감율  출생증감율
# 연도
# 2010   -1.2   4.10
# 2011    0.3  -1.87
# 2012   -2.9   2.61
# 2013   -1.4 -10.49
# 2014    1.1  -0.42
# 2015    4.6  -0.84
# 2016    2.1  -9.00
# 2017    3.6 -13.43
# 2018    6.2 -11.19
# 2019    1.3  -7.58
# 2020    2.7 -11.60

# %%
df11_1=df11.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df11_1.set_xlabel('연도')
df11_1.set_ylabel('증감율')

df11_1.set_title('서울특별시 주택출산증감율')
df11_1.plot(size=(10,7))
plt.show()

# %% [markdown]
# 2010년은 백호해, 2012년은 흑룡해로 출생관련 관심으로 출생률 높음

# %%
#연간증감율관계
sns.regplot(data=df11, x='주택증감율', y='출생증감율', line_kws={'color':'red'})

# %%
#월간증감율관계 
df12=pd.read_excel('/content/drive/MyDrive/주택가격과 출생증감율.xls',index_col='월')

# %%
df12
# Out:
#             주택증감율  출생증감율
# 월
# 2010. 01      0.1 -16.22
# 2010. 02      0.2 -16.22
# 2010. 03      0.1  14.37
# 2010. 04     -0.1  -8.39
# 2010. 05     -0.2  -2.90
# ...           ...    ...
# 2020. 08      0.4  -1.44
# 2020. 09      0.3   5.41
# 2020. 10.     0.2  -5.79
# 2020. 11.     0.2 -10.36
# 2020. 12.     0.3  -1.18
#
# [132 rows x 2 columns]

# %%
sns.regplot(data=df12, x='주택증감율', y='출생증감율', line_kws={'color':'red'})

# %%
sns.jointplot(data=df12, x='주택증감율', y='출생증감율')

# %% [markdown]
# 강남지역 강북지역의 주택매매증감율 출생율증감율
# (강북지역-서북 도심 동북권/ 강남지역-서남 동남권)

# %%
df13=pd.read_excel('/content/drive/MyDrive/강남구역 출생증감율.xlsx',index_col='연도')

# %%
df13.rename(columns = {'증감율' : '출생증감율'},
    inplace = True)

# %%
df15=df13.round(2)

# %%
df15
# Out:
#       출생증감율
# 연도
# 2010  -0.26
# 2011  -0.26
# 2012   4.23
# 2013  -8.86
# 2014   2.36
# 2015   2.30
# 2016  -7.58
# 2017 -10.60
# 2018  -9.00
# 2019  -6.44
# 2020  -9.57

# %%
df14=pd.read_excel('/content/drive/MyDrive/강남주택매매증감율.xls',index_col='연도 ')

# %%
df14.rename(columns = {'강남지역' : '주택증감율'},
    inplace = True)

# %%
df16=df14.join(df15)

# %%
df16
# Out:
#       주택증감율  출생증감율
# 연도
# 2010   -1.0  -0.26
# 2011    0.3  -0.26
# 2012   -3.5   4.23
# 2013   -1.1  -8.86
# 2014    1.2   2.36
# 2015    5.2   2.30
# 2016    2.5  -7.58
# 2017    4.4 -10.60
# 2018    6.5  -9.00
# 2019    1.4  -6.44
# 2020    2.2  -9.57

# %%
df16_1=df16.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df16_1.set_xlabel('연도')
df16_1.set_ylabel('증감율')

df16_1.set_title('강남권 주택출산증감율')
df16_1.plot(size=(10,7))
plt.show()

# %%
df17=pd.read_excel('/content/drive/MyDrive/강북구역 출생증감율.xlsx',index_col='연도')

# %%
df17
# Out:
#       출생증감율
# 연도
# 2010   0.00
# 2011   0.00
# 2012   5.18
# 2013  -8.99
# 2014   1.24
# 2015   1.37
# 2016  -4.53
# 2017 -11.34
# 2018  -9.68
# 2019  -4.16
# 2020 -11.22

# %%
df17.rename(columns = {'증감율' : '출생증감율'},
    inplace = True)

# %%
df18=pd.read_excel('/content/drive/MyDrive/강북주택증감율수정수정.xls',index_col='연도')

# %%
df18
# Out:
#       주택증감율
# 연도
# 2010   -1.4
# 2011    0.3
# 2012   -2.3
# 2013   -1.7
# 2014    1.1
# 2015    3.9
# 2016    1.8
# 2017    2.9
# 2018    5.9
# 2019    1.1
# 2020    3.2

# %%
df19=df18.join(df17)

# %%
df19
# Out:
#       주택증감율  출생증감율
# 연도
# 2010   -1.4   0.00
# 2011    0.3   0.00
# 2012   -2.3   5.18
# 2013   -1.7  -8.99
# 2014    1.1   1.24
# 2015    3.9   1.37
# 2016    1.8  -4.53
# 2017    2.9 -11.34
# 2018    5.9  -9.68
# 2019    1.1  -4.16
# 2020    3.2 -11.22

# %%
df19_1=df19.plot(grid=True,style=['r--*', 'g-o', 'b:*', 'm-.p'])
df19_1.set_xlabel('연도')
df19_1.set_ylabel('증감율')

df19_1.set_title('강북권 주택출산증감율')
df19_1.plot(size=(10,7))
plt.show()
