# %% [markdown]
# <a href="https://colab.research.google.com/github/jessica8403/TIL/blob/master/pratice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x= [1,2,3]
y=[2,4,8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot([-1,0,1], [-5,-1,2])

# %%
x=[1,2,3]
y=[2,4,8]

# %%
plt.plot(x,y)
plt.xlabel('x', color='red')
plt.ylabel('y', color= 'blue')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.plot(x,y)
plt.xticks([1,2,3])
plt.yticks([3,6,9,12])
plt.show()

# %%
x=[1,2,3]
y=[2,4,8]

# %%
plt.plot(x,y, label='data')
plt.legend()

# %%
plt.plot(x,y, label='data')
plt.legend(loc='lower right')

# %%
plt.plot(x,y,linewidth=5)

# %%
plt.plot(x,y,marker='o')

# %%
plt.plot(x,y,marker='o', linestyle='None')

# %%
plt.plot(x,y,marker='v', markersize=10)

# %%
plt.plot(x,y,marker='x', markersize=10)

# %%
plt.plot(x,y,marker='o', markersize=20, markeredgecolor='red')

# %%
plt.plot(x,y,marker='o', markersize=20, markeredgecolor='red', markerfacecolor='yellow')

# %%
plt.plot(x,y,linestyle=':')

# %%
plt.plot(x,y,linestyle='--')

# %%
plt.plot(x,y,linestyle='-.')

# %%
plt.plot(x,y,color='#ff0000')

# %%
plt.plot(x,y,color='b')

# %%
plt.plot(x,y,color='g')

# %%
plt.plot(x,y,'ro--')

# %%
plt.plot(x,y,'bv--')

# %%
plt.plot(x,y,color='g', marker='o', linestyle='None')

# %%
plt.plot(x,y, marker='o', mfc='red', ms=10, mec='blue', ls=':')

# %%
plt.plot(x,y, marker='o', mfc='red', ms=10, alpha=0.3)

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y)

# %%
plt.figure(figsize=(10,5), dpi=50)
plt.plot(x,y)

# %%
plt.figure(facecolor='yellow')
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.savefig('graph.png')
