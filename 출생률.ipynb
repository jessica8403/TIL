# %% [markdown]
# <a href="https://colab.research.google.com/github/jessica8403/TIL/blob/master/%EC%B6%9C%EC%83%9D%EB%A5%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
rawData = pd.read_csv('/content/drive/MyDrive/시군구_성_월별_출생_(10_20).csv', encoding="cp949")

# %%
rawData
# Out:
#      시군구별 2010. 01 2010. 01.1  ... 2020. 12 2020. 12.1 2020. 12.2
# 0    시군구별    계 (명)     남자 (명)  ...    계 (명)     남자 (명)     여자 (명)
# 1   서울특별시     8711       4556  ...     3428       1760       1668
# 2     종로구      114         59  ...       29         13         16
# 3      중구      121         62  ...       40         23         17
# 4     용산구      200        102  ...       93         46         47
# 5     성동구      269        145  ...      114         62         52
# 6     광진구      332        177  ...      110         50         60
# 7    동대문구      258        131  ...      139         70         69
# 8     중랑구      360        200  ...      145         65         80
# 9     성북구      452        229  ...      121         64         57
# 10    강북구      225        109  ...       76         41         35
# 11    도봉구      282        155  ...       89         49         40
# 12    노원구      490        254  ...      177         89         88
# ...

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 397 entries, 시군구별 to 2020. 12.2
# dtypes: object(397)
# memory usage: 83.9+ KB

# %%
type( rawData['시군구별'] )
# Out:
# pandas.core.series.Series

# %%
rawData[ rawData['시군구별'] == '서울특별시' ]
# Out:
#     시군구별 2010. 01 2010. 01.1  ... 2020. 12 2020. 12.1 2020. 12.2
# 1  서울특별시     8711       4556  ...     3428       1760       1668
#
# [1 rows x 397 columns]

# %%
#엑셀 이용
rawData = pd.read_csv('/content/drive/MyDrive/출생률 사본1.csv', encoding="cp949")

# %%
rawData
# Out:
#      시군구별   2010 2010(남) 2010(여)   2011  ... 2019(남) 2019(여)   2020 2020(남) 2020(여)
# 0    시군구별  계 (명)  남자 (명)  여자 (명)  계 (명)  ...  남자 (명)  여자 (명)  계 (명)  남자 (명)  여자 (명)
# 1   서울특별시  93266   48121   45145  91526  ...   27811   25862  47445   24344   23101
# 2     종로구   1107     566     541   1103  ...     334     339    529     268     261
# 3      중구   1170     600     570   1105  ...     426     357    690     348     342
# 4     용산구   2312    1157    1155   2309  ...     684     630   1176     611     565
# 5     성동구   2886    1508    1378   2776  ...    1120    1071   1945    1009     936
# 6     광진구   3366    1761    1605   3184  ...    1022     935   1532     769     763
# 7    동대문구   2880    1490    1390   2947  ...     943     941   1702     860     842
# 8     중랑구   3570    1879    1691   3450  ...    1176    1068   1873     957     916
# 9     성북구   4409    2213    2196   4414  ...    1098    1049   2041    1022    1019
# ...

# %%
rawData=rawData.transpose()

# %%
rawData
# Out:
#              0      1     2     3     4   ...    22    23    24    25    26
# 시군구별       시군구별  서울특별시   종로구    중구   용산구  ...   관악구   서초구   강남구   송파구   강동구
# 2010      계 (명)  93266  1107  1170  2312  ...  4738  4403  4836  6750  4646
# 2010(남)  남자 (명)  48121   566   600  1157  ...  2391  2253  2478  3473  2368
# 2010(여)  여자 (명)  45145   541   570  1155  ...  2347  2150  2358  3277  2278
# 2011      계 (명)  91526  1103  1105  2309  ...  4729  4190  4761  6574  4655
# 2011(남)  남자 (명)  46853   561   550  1190  ...  2418  2167  2448  3444  2428
# 2011(여)  여자 (명)  44673   542   555  1119  ...  2311  2023  2313  3130  2227
# 2012      계 (명)  93914  1100  1215  2411  ...  4596  4439  4903  6859  4590
# 2012(남)  남자 (명)  48353   590   609  1240  ...  2403  2308  2522  3532  2343
# 2012(여)  여자 (명)  45561   510   606  1171  ...  2193  2131  2381  3327  2247
# 2013      계 (명)  84066   873  1022  2129  ...  4140  4081  4551  5963  4070
# ...

# %%
rawData = pd.read_csv('/content/drive/MyDrive/출생률 사본1.csv', encoding="cp949")

# %%
rawData
# Out:
#        연도   2010 2010(남) 2010(여)   2011  ... 2019(남) 2019(여)   2020 2020(남) 2020(여)
# 0    시군구별  계 (명)  남자 (명)  여자 (명)  계 (명)  ...  남자 (명)  여자 (명)  계 (명)  남자 (명)  여자 (명)
# 1   서울특별시  93266   48121   45145  91526  ...   27811   25862  47445   24344   23101
# 2     종로구   1107     566     541   1103  ...     334     339    529     268     261
# 3      중구   1170     600     570   1105  ...     426     357    690     348     342
# 4     용산구   2312    1157    1155   2309  ...     684     630   1176     611     565
# 5     성동구   2886    1508    1378   2776  ...    1120    1071   1945    1009     936
# 6     광진구   3366    1761    1605   3184  ...    1022     935   1532     769     763
# 7    동대문구   2880    1490    1390   2947  ...     943     941   1702     860     842
# 8     중랑구   3570    1879    1691   3450  ...    1176    1068   1873     957     916
# 9     성북구   4409    2213    2196   4414  ...    1098    1049   2041    1022    1019
# ...

# %%
rawData=rawData.transpose()

# %%
rawData
# Out:
#              0      1     2     3     4   ...    22    23    24    25    26
# 연도         시군구별  서울특별시   종로구    중구   용산구  ...   관악구   서초구   강남구   송파구   강동구
# 2010      계 (명)  93266  1107  1170  2312  ...  4738  4403  4836  6750  4646
# 2010(남)  남자 (명)  48121   566   600  1157  ...  2391  2253  2478  3473  2368
# 2010(여)  여자 (명)  45145   541   570  1155  ...  2347  2150  2358  3277  2278
# 2011      계 (명)  91526  1103  1105  2309  ...  4729  4190  4761  6574  4655
# 2011(남)  남자 (명)  46853   561   550  1190  ...  2418  2167  2448  3444  2428
# 2011(여)  여자 (명)  44673   542   555  1119  ...  2311  2023  2313  3130  2227
# 2012      계 (명)  93914  1100  1215  2411  ...  4596  4439  4903  6859  4590
# 2012(남)  남자 (명)  48353   590   609  1240  ...  2403  2308  2522  3532  2343
# 2012(여)  여자 (명)  45561   510   606  1171  ...  2193  2131  2381  3327  2247
# 2013      계 (명)  84066   873  1022  2129  ...  4140  4081  4551  5963  4070
# ...

# %%
rawData
# Out:
#        연도   2010 2010(남) 2010(여)   2011  ... 2019(남) 2019(여)   2020 2020(남) 2020(여)
# 0    시군구별  계 (명)  남자 (명)  여자 (명)  계 (명)  ...  남자 (명)  여자 (명)  계 (명)  남자 (명)  여자 (명)
# 1   서울특별시  93266   48121   45145  91526  ...   27811   25862  47445   24344   23101
# 2     종로구   1107     566     541   1103  ...     334     339    529     268     261
# 3      중구   1170     600     570   1105  ...     426     357    690     348     342
# 4     용산구   2312    1157    1155   2309  ...     684     630   1176     611     565
# 5     성동구   2886    1508    1378   2776  ...    1120    1071   1945    1009     936
# 6     광진구   3366    1761    1605   3184  ...    1022     935   1532     769     763
# 7    동대문구   2880    1490    1390   2947  ...     943     941   1702     860     842
# 8     중랑구   3570    1879    1691   3450  ...    1176    1068   1873     957     916
# 9     성북구   4409    2213    2196   4414  ...    1098    1049   2041    1022    1019
# ...

# %%
rawData = pd.read_csv('/content/drive/MyDrive/출생률 사본1.csv', encoding="cp949")

# %%
rawData
# Out:
#     시군구별   2010년  2010년(남)  2010년(여)  ...  2019년(여)  2020년  2020년(남)  2020년(여)
# 0   서울특별시  93266     48121     45145  ...     25862  47445     24344     23101
# 1     종로구   1107       566       541  ...       339    529       268       261
# 2      중구   1170       600       570  ...       357    690       348       342
# 3     용산구   2312      1157      1155  ...       630   1176       611       565
# 4     성동구   2886      1508      1378  ...      1071   1945      1009       936
# 5     광진구   3366      1761      1605  ...       935   1532       769       763
# 6    동대문구   2880      1490      1390  ...       941   1702       860       842
# 7     중랑구   3570      1879      1691  ...      1068   1873       957       916
# 8     성북구   4409      2213      2196  ...      1049   2041      1022      1019
# 9     강북구   2801      1412      1389  ...       590   1049       557       492
# 10    도봉구   3158      1640      1518  ...       697   1218       631       587
# ...
